# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt

# %%
df=pd.read_csv('out.csv')

# %%
df.keys()
# Out:
# Index(['index', 'Bool_hp', 'Bool_hpdhw', 'E_bu', 'E_budhw', 'E_cons', 'E_hp',
#        'E_hpdhw', 'Q_dhwst_hd', 'Q_hp_sh', 'Q_hp_ts', 'Q_loss_dhwst',
#        'Q_loss_ts', 'Q_ts', 'Q_ts_delta', 'Q_ts_sh', 'T_dhwst', 'T_ts',
#        'Set_T', 'Temp', 'Req_kWh', 'Req_kWh_DHW', 'Temp_supply',
#        'Temp_supply_tank', 'COP_SH', 'COP_tank', 'COP_DHW', 'hp_sh_cons',
#        'hp_tank_cons', 'hp_dhw_cons', 'Price_flat', 'Price_DT', 'Export_price',
#        'Price_flat_mod', 'Price_DT_mod', 'T_var', 'Cooling', 'season',
#        'T_aux_supply'],
#       dtype='object')

# %%
df=df.round(4)

# %%
df.T_ts.plot()

# %%
df.E_cons.plot()
df.E_hp.plot()
df.Q_ts_sh.plot()
df.Price_DT.plot()
plt.legend()
